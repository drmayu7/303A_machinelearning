# %% [markdown]
# # Descriptive Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import os 
os.getcwd()
# Out:
# 'C:\\Users\\narma\\Desktop\\303 Machine Learning\\303A_machinelearning'

# %%
#---To view the Imputed dataset 
df = pd.read_csv("Dataset/processed/breast-cancer-wisconsin-imputed.csv")

df #---The imputed dataset
# Out:
#      sample_id  cl_thcknss  size_cell_un  shape_cell_un  marg_adhesion  \
# 0      1000025         5.0           1.0            1.0            1.0
# 1      1002945         5.0           4.0            4.0            5.0
# 2      1015425         3.0           1.0            1.0            1.0
# 3      1016277         6.0           8.0            8.0            1.0
# 4      1017023         4.0           1.0            1.0            3.0
# ..         ...         ...           ...            ...            ...
# 694     776715         3.0           1.0            1.0            1.0
# 695     841769         2.0           1.0            1.0            1.0
# 696     888820         5.0          10.0           10.0            3.0
# 697     897471         4.0           8.0            6.0            4.0
# 698     897471         4.0           8.0            8.0            5.0
#
#      size_cell_single  bare_nucl  bl_chrmatn  nrml_nucleo  mitoses  class
# 0                 2.0        1.0         3.0          1.0      1.0      2
# 1                 7.0       10.0         3.0          2.0      1.0      2
# 2                 2.0        2.0         3.0          1.0      1.0      2
# 3                 3.0        4.0         3.0          7.0      1.0      2
# 4                 2.0        1.0         3.0          1.0      1.0      2
# ..                ...        ...         ...          ...      ...    ...
# 694               3.0        2.0         1.0          1.0      1.0      2
# 695               2.0        1.0         1.0          1.0      1.0      2
# 696               7.0        3.0         8.0         10.0      2.0      4
# 697               3.0        4.0        10.0          6.0      1.0      4
# 698               4.0        5.0        10.0          4.0      1.0      4
#
# [699 rows x 11 columns]

# %%
#---To view the top 5 rows of the dataset
#---To confirm the values are same as the original dataset

print('The top 5 rows of the dataset:')
df.head()
# Out:
# The top 5 rows of the dataset:
#    sample_id  cl_thcknss  size_cell_un  shape_cell_un  marg_adhesion  \
# 0    1000025         5.0           1.0            1.0            1.0
# 1    1002945         5.0           4.0            4.0            5.0
# 2    1015425         3.0           1.0            1.0            1.0
# 3    1016277         6.0           8.0            8.0            1.0
# 4    1017023         4.0           1.0            1.0            3.0
#
#    size_cell_single  bare_nucl  bl_chrmatn  nrml_nucleo  mitoses  class
# 0               2.0        1.0         3.0          1.0      1.0      2
# 1               7.0       10.0         3.0          2.0      1.0      2
# 2               2.0        2.0         3.0          1.0      1.0      2
# 3               3.0        4.0         3.0          7.0      1.0      2
# 4               2.0        1.0         3.0          1.0      1.0      2

# %%
#---To view the bottom 5 rows of the dataset
#---To confirm the values are same as the original dataset

print('The bottom 5 rows of the dataset:')
df.tail()
# Out:
# The bottom 5 rows of the dataset:
#      sample_id  cl_thcknss  size_cell_un  shape_cell_un  marg_adhesion  \
# 694     776715         3.0           1.0            1.0            1.0
# 695     841769         2.0           1.0            1.0            1.0
# 696     888820         5.0          10.0           10.0            3.0
# 697     897471         4.0           8.0            6.0            4.0
# 698     897471         4.0           8.0            8.0            5.0
#
#      size_cell_single  bare_nucl  bl_chrmatn  nrml_nucleo  mitoses  class
# 694               3.0        2.0         1.0          1.0      1.0      2
# 695               2.0        1.0         1.0          1.0      1.0      2
# 696               7.0        3.0         8.0         10.0      2.0      4
# 697               3.0        4.0        10.0          6.0      1.0      4
# 698               4.0        5.0        10.0          4.0      1.0      4

# %%
#---To view the total number of columns and rows in the dataset

print(f'''
Number of columns in dataset : {df.shape[1]}
\n
Number of rows in dataset : {df.shape[0]}
''')
# Out:
# Number of columns in dataset : 11
#
#
# Number of rows in dataset : 699

# %%
#---Detect datatype for each column and null values

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sample_id         699 non-null    int64
#  1   cl_thcknss        699 non-null    float64
#  2   size_cell_un      699 non-null    float64
#  3   shape_cell_un     699 non-null    float64
#  4   marg_adhesion     699 non-null    float64
#  5   size_cell_single  699 non-null    float64
#  6   bare_nucl         699 non-null    float64
#  7   bl_chrmatn        699 non-null    float64
#  8   nrml_nucleo       699 non-null    float64
#  9   mitoses           699 non-null    float64
#  10  class             699 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 60.2 KB

# %%
#---Remove the sample_id column

df_2 = df.drop(columns=['sample_id'])
print('Imputed Breast cancer Wisconsin dataset without sample_id column: ')

df_2 #---Breast cancer wisconsin dataset WITHOUT the sample_id column
# Out:
# Imputed Breast cancer Wisconsin dataset without sample_id column:
#      cl_thcknss  size_cell_un  shape_cell_un  marg_adhesion  size_cell_single  \
# 0           5.0           1.0            1.0            1.0               2.0
# 1           5.0           4.0            4.0            5.0               7.0
# 2           3.0           1.0            1.0            1.0               2.0
# 3           6.0           8.0            8.0            1.0               3.0
# 4           4.0           1.0            1.0            3.0               2.0
# ..          ...           ...            ...            ...               ...
# 694         3.0           1.0            1.0            1.0               3.0
# 695         2.0           1.0            1.0            1.0               2.0
# 696         5.0          10.0           10.0            3.0               7.0
# 697         4.0           8.0            6.0            4.0               3.0
# 698         4.0           8.0            8.0            5.0               4.0
#
#      bare_nucl  bl_chrmatn  nrml_nucleo  mitoses  class
# 0          1.0         3.0          1.0      1.0      2
# 1         10.0         3.0          2.0      1.0      2
# 2          2.0         3.0          1.0      1.0      2
# 3          4.0         3.0          7.0      1.0      2
# 4          1.0         3.0          1.0      1.0      2
# ..         ...         ...          ...      ...    ...
# 694        2.0         1.0          1.0      1.0      2
# 695        1.0         1.0          1.0      1.0      2
# 696        3.0         8.0         10.0      2.0      4
# 697        4.0        10.0          6.0      1.0      4
# 698        5.0        10.0          4.0      1.0      4
#
# [699 rows x 10 columns]

# %%
#---To view the description of data in the dataframe

df_2.describe()
# Out:
#        cl_thcknss  size_cell_un  shape_cell_un  marg_adhesion  \
# count  699.000000    699.000000     699.000000     699.000000
# mean     4.417740      3.134478       3.207439       2.806867
# std      2.815741      3.051459       2.971913       2.855379
# min      1.000000      1.000000       1.000000       1.000000
# 25%      2.000000      1.000000       1.000000       1.000000
# 50%      4.000000      1.000000       1.000000       1.000000
# 75%      6.000000      5.000000       5.000000       4.000000
# max     10.000000     10.000000      10.000000      10.000000
#
#        size_cell_single   bare_nucl  bl_chrmatn  nrml_nucleo     mitoses  \
# count        699.000000  699.000000  699.000000   699.000000  699.000000
# mean           3.216023    3.526567    3.437768     2.866953    1.589413
# std            2.214300    3.618696    2.438364     3.053634    1.715078
# min            1.000000    0.605359    1.000000     1.000000    1.000000
# 25%            2.000000    1.000000    2.000000     1.000000    1.000000
# 50%            2.000000    1.000000    3.000000     1.000000    1.000000
# 75%            4.000000    5.955306    5.000000     4.000000    1.000000
# max           10.000000   10.000000   10.000000    10.000000   10.000000
#
#             class
# count  699.000000
# mean     2.689557
# std      0.951273
# min      2.000000
# 25%      2.000000
# 50%      2.000000
# 75%      4.000000
# max      4.000000

# %%
#---To view the class in the dataframe

df_2.groupby('class').size()
# Out:
# class
# 2    458
# 4    241
# dtype: int64

# %%
#---To observe the skewness of the dataframe

df_2.skew()
# Out:
# cl_thcknss          0.592859
# size_cell_un        1.233137
# shape_cell_un       1.161859
# marg_adhesion       1.524468
# size_cell_single    1.712172
# bare_nucl           1.002818
# bl_chrmatn          1.099969
# nrml_nucleo         1.422261
# mitoses             3.560658
# class               0.654564
# dtype: float64

# %%
#---To observe the kurtosis of the dataframe

df_2.kurt()
# Out:
# cl_thcknss          -0.623715
# size_cell_un         0.098803
# shape_cell_un        0.007011
# marg_adhesion        0.987947
# size_cell_single     2.169066
# bare_nucl           -0.762128
# bl_chrmatn           0.184621
# nrml_nucleo          0.474269
# mitoses             12.657878
# class               -1.576064
# dtype: float64

# %% [markdown]
# # Data Visualisations

# %%
#---Histograms

df_2.hist(figsize=(10,10))
plt.show()

# %%
#---Density Plots

df_2.plot(kind='density', subplots=True, layout=(4,3), sharex=False, figsize=(15,10)) 
plt.show()

# %%
#---Boxplots
df_2.plot(kind='box', subplots=True, layout=(4,3), sharex=False, sharey=False, figsize=(10,10)) 
plt.show()

# %%
#---Pearson's Test using seaborn

corr = df_2.corr()
f, ax = plt.subplots(figsize=(8, 5))
mask = np.triu(np.ones_like(corr, dtype=bool))
cmap = sb.diverging_palette(230, 20, as_cmap=True)
sb.heatmap(corr, annot=True, mask = mask, cmap=cmap)
plt.title("Correlation Coefficient (Pearson-Test) for Multivariate Features of Breast Cancer Wisconsin Dataset")
plt.show()

# %%
#---Visualising a correlation heatmap using seaborn

print("A correlation heatmap is shown as below:")
plt.figure(figsize=(8,6))
sb.set_theme(style="white")
corr = df_2.corr()
heatmap = sb.heatmap(corr, annot=True, cmap="BuPu", fmt='.1g')
plt.title("Heatmap of Breast cancer Wisconsin Dataset")
plt.show()
# Out:
# A correlation heatmap is shown as below:
